# %%
#import libraries:

import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#read the oecddata.csv in a dataframe 
df = pd.read_csv('oecddata.csv')

# %%
df.head(10)
# Out:
#   COUNTRY Country COMMODITY Commodity VARIABLE  \
# 0     WLD   World        WT     Wheat       QP
# 1     WLD   World        WT     Wheat       QP
# 2     WLD   World        WT     Wheat       QP
# 3     WLD   World        WT     Wheat       QP
# 4     WLD   World        WT     Wheat       QP
# 5     WLD   World        WT     Wheat       QP
# 6     WLD   World        WT     Wheat       QP
# 7     WLD   World        WT     Wheat       QP
# 8     WLD   World        WT     Wheat       QP
# 9     WLD   World        WT     Wheat       QP
#
#                                             Variable  TIME  Time        Value  \
# 0  Production, kt (for Biofuels in millions of li...  1995  1995  545912.4486
# 1  Production, kt (for Biofuels in millions of li...  1996  1996  584408.9740
# 2  Production, kt (for Biofuels in millions of li...  1997  1997  613038.9401
# 3  Production, kt (for Biofuels in millions of li...  1998  1998  594715.5676
# ...

# %%
#View all the unique values in a column
def check_unique_values(df):
    for col in df.columns:
        print(col, df[col].unique())
check_unique_values(df)
# Out:
# COUNTRY ['WLD' 'O29' 'NME' 'DVD' 'DVG' 'LDC' 'OED' 'AUS' 'CAN' 'CHL' 'E27' 'ISR'
#  'JPN' 'KOR' 'MEX' 'NZL' 'TUR' 'USA' 'EUR' 'KAZ' 'RUS' 'UKR' 'AFR' 'DZA'
#  'EGY' 'ETH' 'GHA' 'MOZ' 'NGA' 'SSA' 'ZAF' 'SDN' 'TZA' 'ZMB' 'LAC' 'ARG'
#  'BRA' 'COL' 'HTI' 'PER' 'PRY' 'URY' 'ASP' 'BGD' 'CHN' 'IND' 'IDN' 'IRN'
#  'MYS' 'PAK' 'PHL' 'SAU' 'THA' 'VNM']
# Country ['World' 'OECD' 'Non-OECD' 'Developed' 'Developing'
#  'Least Developed Countries' 'OECD countries' 'Australia' 'Canada' 'Chile'
#  'European Union-27' 'Israel' 'Japan' 'Korea' 'Mexico' 'New Zealand'
#  'Türkiye' 'United States' 'EUROPE' 'Kazakhstan' 'Russia' 'Ukraine'
#  'AFRICA' 'Algeria' 'Egypt' 'Ethiopia' 'Ghana' 'Mozambique' 'Nigeria'
#  'Sub Saharan Africa' 'Republic of South Africa' 'Sudan' 'Tanzania'
#  'Zambia' 'LATIN AMERICA AND CARIBBEAN' 'Argentina' 'Brazil' 'Colombia'
#  'Haiti' 'Peru' 'Paraguay' 'Uruguay' 'ASIA' 'Bangladesh' 'China' 'India'
#  'Indonesia' 'Iran' 'Malaysia' 'Pakistan' 'Philippines' 'Saudi Arabia'
# ...

# %% [markdown]
# We will be dropping columns that are not relevant

# %%
#Drop 'COUNTRY', "COMMODITY", 'TIME','Flag Codes' and 'Flags' columns in the dataframe: df

df = df.drop(['COUNTRY', "COMMODITY", 'TIME','Flag Codes','Flags'], axis=1)

# %%
df
# Out:
#         Country   Commodity VARIABLE  \
# 0         World       Wheat       QP
# 1         World       Wheat       QP
# 2         World       Wheat       QP
# 3         World       Wheat       QP
# 4         World       Wheat       QP
# ...         ...         ...      ...
# 366498  VietNam  Sugar cane      YLD
# 366499  VietNam  Sugar cane      YLD
# 366500  VietNam  Sugar cane      YLD
# 366501  VietNam  Sugar cane      YLD
# 366502  VietNam  Sugar cane      YLD
#
#                                                  Variable  Time          Value
# 0       Production, kt (for Biofuels in millions of li...  1995  545912.448600
# 1       Production, kt (for Biofuels in millions of li...  1996  584408.974000
# 2       Production, kt (for Biofuels in millions of li...  1997  613038.940100
# 3       Production, kt (for Biofuels in millions of li...  1998  594715.567600
# 4       Production, kt (for Biofuels in millions of li...  1999  588441.328900
# ...

# %%
#Change the 'Value' column to integer:

df['Value'] = df['Value'].astype(int)

#Check that the change was successful:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366503 entries, 0 to 366502
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Country    366503 non-null  object
#  1   Commodity  366503 non-null  object
#  2   VARIABLE   366503 non-null  object
#  3   Variable   366503 non-null  object
#  4   Time       366503 non-null  int64
#  5   Value      366503 non-null  int32
# dtypes: int32(1), int64(1), object(4)
# memory usage: 15.4+ MB

# %%
df.sample(20)
# Out:
#                    Country              Commodity VARIABLE  \
# 74938            Indonesia                   Rice       QC
# 64289               AFRICA                   Rice       FO
# 96752             Paraguay               Oilseeds       FO
# 249687               China            Cheese (pw)       PP
# 69664            Argentina                   Rice       QP
# 128066             Nigeria         Vegetable oils       QC
# 61136          New Zealand                   Rice       AH
# 290413              Russia            Sugar (rse)       IM
# 166184               Sudan          Pigmeat (cwe)       PC
# 242462       United States            Cheese (pw)       EX
# 14533   Sub Saharan Africa                  Wheat       ST
# 260088          Mozambique  Skim milk powder (pw)       FO
# 52124             Pakistan          Coarse grains      YLD
# 23240            Indonesia                  Wheat       BF
# 168155            Colombia          Pigmeat (cwe)       EX
# ...

# %%
df.Variable.unique()
# Out:
# array(['Production, kt (for Biofuels in millions of litres)',
#        'Imports, kt (for Biofuels in millions of litres)',
#        'Consumption, kt (for Biofuels in millions of litres)',
#        'Ending stocks, kt (for Biofuels in millions of litres)',
#        'Exports, kt (for Biofuels in millions of litres)',
#        'Trade balance, kt (for Biofuels in millions of litres)',
#        'Area harvested, 000 ha', 'Feed, kt', 'Food, kt',
#        'Biofuel use, kt',
#        'Other use, kt (for Biofuels in millions of litres)', 'Yield',
#        'World Price, USD/t (for Biofuels USD/100 litres)',
#        'Consumption per capita, kg',
#        'Producer price, local currency/t (for Biofuels local currency/ 100 litres)',
#        'Crush, kt', 'Cow inventory, 000 hd',
#        'Ethanol production from Biomass, in millions of litres',
#        'Biodiesel production from Biomass, in millions of litres'],
#       dtype=object)
